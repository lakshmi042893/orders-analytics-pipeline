# %%
def load_config(environment='dev'):
    """Load configuration for specified environment"""
    
    print(f"🔧 Loading {environment.upper()} configuration...")
    
    if environment == 'dev':
        config = {
            "environment": "dev",
            "branch": "dev_new",
            "catalog": "databricks_catalog_new",
            "schemas": {
                "bronze": "dev_bronze",
                "silver": "dev_silver",
                "gold": "dev_gold"
            },
            "storage": {
                "account": "databricksete123",
                "container": "source",
                "landing": {
                    "orders": "abfss://source@databricksete123.dfs.core.windows.net/orders/",
                    "customers": "abfss://source@databricksete123.dfs.core.windows.net/customers/",
                    "products": "abfss://source@databricksete123.dfs.core.windows.net/products/",
                    "region": "abfss://source@databricksete123.dfs.core.windows.net/region/"
                },
                "checkpoint_base": "abfss://source@databricksete123.dfs.core.windows.net/checkpoints/dev/"
            }
        }
    elif environment == 'preprod':
        config = {
            "environment": "preprod",
            "branch": "preprod_new",
            "catalog": "databricks_catalog_new",
            "schemas": {
                "bronze": "preprod_bronze",
                "silver": "preprod_silver",
                "gold": "preprod_gold"
            },
            "storage": {
                "account": "databricksete123",
                "container": "source",
                "landing": {
                    "orders": "abfss://source@databricksete123.dfs.core.windows.net/orders/",
                    "customers": "abfss://source@databricksete123.dfs.core.windows.net/customers/",
                    "products": "abfss://source@databricksete123.dfs.core.windows.net/products/",
                    "region": "abfss://source@databricksete123.dfs.core.windows.net/region/"
                },
                "checkpoint_base": "abfss://source@databricksete123.dfs.core.windows.net/checkpoints/preprod/"
            }
        }
    elif environment == 'prod':
        config = {
            "environment": "prod",
            "branch": "main",
            "catalog": "databricks_catalog_new",
            "schemas": {
                "bronze": "prod_bronze",
                "silver": "prod_silver",
                "gold": "prod_gold"
            },
            "storage": {
                "account": "databricksete123",
                "container": "source",
                "landing": {
                    "orders": "abfss://source@databricksete123.dfs.core.windows.net/orders/",
                    "customers": "abfss://source@databricksete123.dfs.core.windows.net/customers/",
                    "products": "abfss://source@databricksete123.dfs.core.windows.net/products/",
                    "region": "abfss://source@databricksete123.dfs.core.windows.net/region/"
                },
                "checkpoint_base": "abfss://source@databricksete123.dfs.core.windows.net/checkpoints/prod/"
            }
        }
    
    print(f"✅ Loaded {environment.upper()} config!")
    return config
